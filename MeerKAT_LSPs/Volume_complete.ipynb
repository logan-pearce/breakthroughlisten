# %%
import pandas as pd
import numpy as np
import MySQLdb
import os
import matplotlib.pyplot as plt
from matplotlib import pyplot as plt
from astropy.coordinates import SkyCoord
from astropy import units as u
import numpy as np

# %%
db = MySQLdb.connect(host='104.154.94.28',db='loganp',\
                     read_default_file="~/.my.cnf",\
                     autocommit=True,\
                     local_infile = 1)

# %%
string="SELECT * FROM `master_gaia_database` \
        WHERE `decl` BETWEEN -90.0 and 45.0\
        AND `dist_c`<160.0;"
targets = pd.read_sql(string, con=db)

# %%
targets.shape
# Out:
# (1169411, 55)

# %%
targets['project'],targets['name']='Volume Complete','Volume Complete'
targets
# Out:
#            Ind            source_id  ref_epoch        ra  ra_error       decl  \
# 0            0  5853498713160606720     2015.5  217.3930  0.057653 -62.676200
# 1            1    76868614540049408     2015.5   30.0588  0.081253  13.044300
# 2            2   625453654702751872     2015.5  154.8990  0.057573  19.869800
# 3            3  5918660719981686144     2015.5  266.6340  0.175810 -57.324900
# 4            4  4109030160308317312     2015.5  258.8350  0.274004 -26.607700
# 5            5  6324325225803432320     2015.5  218.5680  0.076310 -12.517000
# 6            6  1237090738916392704     2015.5  222.8480  0.199844  19.100300
# 7            7  1784473016438653056     2015.5  322.4080  0.072625  17.644900
# 8            8  5153091836072107136     2015.5   45.4625  0.065618 -16.594500
# 9            9  3828238392559860992     2015.5  153.0730  0.066020  -3.746710
# 10          10  2879455480941956736     2015.5  355.7810  0.171592  36.536300
# ...

# %%
targets.to_csv('../Our_targets/volume_complete.csv',index=False)
