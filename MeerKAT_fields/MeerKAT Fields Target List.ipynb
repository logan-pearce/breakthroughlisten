# %%
import pandas as pd
import numpy as np
import MySQLdb
import os
import matplotlib.pyplot as plt
from matplotlib import pyplot as plt
from astropy.coordinates import SkyCoord
import astropy.coordinates as coord
from astropy import units as u
import numpy as np

# %%
db = MySQLdb.connect(host='104.154.94.28',db='loganp',\
                     read_default_file="~/.my.cnf",\
                     autocommit=True,\
                     local_infile = 1)
c=db.cursor()

# %%
# LADUMA Field:
RA = '03 31 00'
Dec = '-27 36 00'
# Convert RA/Dec from hour angle to degrees:
c = SkyCoord(ra=RA, dec=Dec, unit=(u.hourangle, u.deg))
L_RA1=c.ra.radian
L_Dec1=c.dec.radian

RA = '03 33 30'
Dec = '-28 00 00'
# Convert RA/Dec from hour angle to degrees:
c = SkyCoord(ra=RA, dec=Dec, unit=(u.hourangle, u.deg))
L_RA2=c.ra.radian
L_Dec2=c.dec.radian

L_RA = np.array([L_RA1,L_RA2,L_RA2,L_RA1])
L_Dec = np.array([L_Dec2,L_Dec2,L_Dec1,L_Dec1])


# Pulsar Timing:
RA = '00 00 00'
Dec = '00 00 00'
# Convert RA/Dec from hour angle to degrees:
c = SkyCoord(ra=RA, dec=Dec, unit=(u.hourangle, u.deg))
P_RA1=c.ra.radian
P_Dec1=c.dec.radian

RA = '12 00 00'
Dec = '-60 00 00'
# Convert RA/Dec from hour angle to degrees:
c = SkyCoord(ra=RA, dec=Dec, unit=(u.hourangle, u.deg))
P_RA2=c.ra.radian
P_Dec2=c.dec.radian

P_RA = np.array([P_RA1,P_RA2,P_RA2,P_RA1])
P_Dec = np.array([P_Dec2,P_Dec2,P_Dec1,P_Dec1])

# MIGHTEE:
# One:
RA = '00 30 30'
Dec = '-42 00 00'
# Convert RA/Dec from hour angle to degrees:
c = SkyCoord(ra=RA, dec=Dec, unit=(u.hourangle, u.deg))
M_RA1=c.ra.radian
M_Dec1=c.dec.radian

RA = '00 46 00'
Dec = '-46 00 00'
# Convert RA/Dec from hour angle to degrees:
c = SkyCoord(ra=RA, dec=Dec, unit=(u.hourangle, u.deg))
M_RA2=c.ra.radian
M_Dec2=c.dec.radian

M_RA_1 = np.array([M_RA1,M_RA2,M_RA2,M_RA1])
M_Dec_1 = np.array([M_Dec2,M_Dec2,M_Dec1,M_Dec1])

# Two:
RA = '02 12 30'
Dec = '-02 30 00'
# Convert RA/Dec from hour angle to degrees:
c = SkyCoord(ra=RA, dec=Dec, unit=(u.hourangle, u.deg))
M_RA1=c.ra.radian
M_Dec1=c.dec.radian

RA = '02 30 00'
Dec = '-06 30 00'
# Convert RA/Dec from hour angle to degrees:
c = SkyCoord(ra=RA, dec=Dec, unit=(u.hourangle, u.deg))
M_RA2=c.ra.radian
M_Dec2=c.dec.radian

M_RA_2 = np.array([M_RA1,M_RA2,M_RA2,M_RA1])
M_Dec_2 = np.array([M_Dec2,M_Dec2,M_Dec1,M_Dec1])

# Three:
RA = '10 00 18'
Dec = '02 54 21'
# Convert RA/Dec from hour angle to degrees:
c = SkyCoord(ra=RA, dec=Dec, unit=(u.hourangle, u.deg))
M_RA1=c.ra.radian
M_Dec1=c.dec.radian

RA = '10 00 38'
Dec = '01 30 00'
# Convert RA/Dec from hour angle to degrees:
c = SkyCoord(ra=RA, dec=Dec, unit=(u.hourangle, u.deg))
M_RA2=c.ra.radian
M_Dec2=c.dec.radian

M_RA_3 = np.array([M_RA1,M_RA2,M_RA2,M_RA1])
M_Dec_3 = np.array([M_Dec2,M_Dec2,M_Dec1,M_Dec1])

# Fornax:
RA = '03 10 00'
Dec = '-29 54 00'
# Convert RA/Dec from hour angle to degrees:
c = SkyCoord(ra=RA, dec=Dec, unit=(u.hourangle, u.deg))
F_RA1=c.ra.radian
F_Dec1=c.dec.radian

RA = '03 54 30'
Dec = '-38 35 00'
# Convert RA/Dec from hour angle to degrees:
c = SkyCoord(ra=RA, dec=Dec, unit=(u.hourangle, u.deg))
F_RA2=c.ra.radian
F_Dec2=c.dec.radian

F_RA = np.array([F_RA1,F_RA2,F_RA2,F_RA1])
F_Dec = np.array([F_Dec2,F_Dec2,F_Dec1,F_Dec1])

# TRAPUM:
RA = '00 00 00'
Dec = '20 00 00'
# Convert RA/Dec from hour angle to degrees:
c = SkyCoord(ra=RA, dec=Dec, unit=(u.hourangle, u.deg))
T_RA1=c.ra.radian
T_Dec1=c.dec.radian

RA = '12 00 00'
Dec = '-50 00 00'
# Convert RA/Dec from hour angle to degrees:
c = SkyCoord(ra=RA, dec=Dec, unit=(u.hourangle, u.deg))
T_RA2=c.ra.radian
T_Dec2=c.dec.radian

T_RA = np.array([T_RA1,T_RA2,T_RA2,T_RA1])
T_Dec = np.array([T_Dec2,T_Dec2,T_Dec1,T_Dec1])

# MHONGOOSE:
RA = '00 00 00'
Dec = '-10 00 00'
# Convert RA/Dec from hour angle to degrees:
c = SkyCoord(ra=RA, dec=Dec, unit=(u.hourangle, u.deg))
MM_RA1=c.ra.radian
MM_Dec1=c.dec.radian

RA = '12 00 00'
Dec = '-53 00 00'
# Convert RA/Dec from hour angle to degrees:
c = SkyCoord(ra=RA, dec=Dec, unit=(u.hourangle, u.deg))
MM_RA2=c.ra.radian
MM_Dec2=c.dec.radian

MM_RA = np.array([MM_RA1,MM_RA2,MM_RA2,MM_RA1])
MM_Dec = np.array([MM_Dec2,MM_Dec2,MM_Dec1,MM_Dec1])

# %%
# %matplotlib notebook

fig = plt.figure(figsize=(10, 5))
ax = fig.add_subplot(111, projection="mollweide", axisbg ='LightCyan')
ax.set_xticklabels(['14h','16h','18h','20h','22h','0h','2h','4h','6h','8h','10h'],color='grey')
ax.grid(True)
ax.fill(T_RA, T_Dec, "magenta", alpha=0.3,label='TRAPUM')
ax.fill(-T_RA, T_Dec, "magenta", alpha=0.3)
ax.fill(L_RA,L_Dec,"blue",zorder=10,label="LADUMA")
ax.fill(P_RA, P_Dec, "orange", alpha=0.5,label="Pulsar Timing")
ax.fill(-P_RA, P_Dec, "orange", alpha=0.5)
ax.fill(M_RA_1, M_Dec_1, "red", alpha=0.5,label="MIGHTEE",zorder=10)
ax.fill(M_RA_2, M_Dec_2, "red", alpha=0.5,zorder=10)
ax.fill(M_RA_3, M_Dec_3, "red", alpha=0.5,zorder=10)
ax.fill(F_RA, F_Dec, "green", alpha=0.5,label="FORNAX",zorder=10)
ax.fill(MM_RA, MM_Dec, "lightgrey", alpha=0.5,label="MHONGOOSE")
ax.fill(-MM_RA, MM_Dec, "lightgrey", zorder=1,alpha=0.5)
plt.legend(fontsize=10)
plt.show()
plt.savefig('fields.png',format='png',dpi=300)
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# ## Fornax field:

# %%
f = pd.read_sql("SELECT source_id,parallax,parallax_error,bp_rp,phot_g_mean_mag,ra,decl FROM meerkat_gaiadr2_fornax\
                WHERE 1", con=db)
#f

# %%
# GBP - GRP color:
color = f['bp_rp'].values
# Apparent G band magnitude:
gmag = f['phot_g_mean_mag'].values 

# Convert to absolute magnitude (excluding extinction for now):
GMag = gmag + 5 + 5*np.log10(f['parallax'].values/1000)

# %matplotlib notebook
fig, ax = plt.subplots(ncols=1, sharey=True, figsize=(7, 7))
hb = ax.hexbin(color,GMag,gridsize=500,cmap='inferno',bins='log',mincnt=1)
ax.set_title("CMD of Gaia sources in within Fornax field")
ax.set_ylabel('M$_{G}$')
ax.set_xlabel('G$_{BP}$-G$_{RP}$')
ax.invert_yaxis()
cb = fig.colorbar(hb, ax=ax)
cb.set_label('log10(count)')
plt.annotate('{0} stars'.format(color.shape[0]),xy=(0.55,0.85),xycoords='figure fraction')
plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %%
pra = coord.Angle(f['ra'].values*u.degree)
pra = pra.wrap_at(180*u.degree)
pdec = coord.Angle(f['decl'].values*u.degree)

# %matplotlib notebook
fig = plt.figure(figsize=(8,6))
ax = fig.add_subplot(111, projection="mollweide")
hb = ax.hexbin(pra.radian, pdec.radian,gridsize=500,cmap='inferno',bins='log',mincnt=1)
#ax.scatter(pra.radian, pdec.radian,alpha=0.2,color='blue',s=5)
ax.set_xticklabels(['14h','16h','18h','20h','22h','0h','2h','4h','6h','8h','10h'],color='grey')
ax.set_title('Stars within Fornax field \n')
cb = fig.colorbar(hb, ax=ax,orientation="horizontal", pad=0.1)
cb.set_label('log10(count)')
ax.grid(True)
plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %%
import time
start = time.time()
d=np.zeros(len(color))
print 'Computing distances'
count=0
L=1350
for i in range(len(d)):
    coeff = np.array([(1./L),(-2),((f['parallax'].values[i]/1000.)/((f['parallax_error'].values[i]/1000.))**2),\
                      -(1./((f['parallax_error'].values[i]/1000.)**2))])
    g = np.roots(coeff)
    # Find the number of real roots:
    reals = np.isreal(g)
    realsum = np.sum(reals)
    # If there is one real root, that root is the  mode:
    if realsum == 1:
        gd = np.real(g[np.where(reals)[0]])
    # If all roots are real:
    elif realsum == 3:
        if f['parallax'].values[i] >= 0:
            # Take the smallest root:
            gd = np.min(g)
        elif f['parallax'].values[i] < 0:
            # Take the positive root (there should be only one):
            gd = g[np.where(g>0)[0]]
    d[i] = gd
    
    count = count+1
    mod=count%10000
    if mod==0:
        print 'Finished ',count,' sources'
print 'Finished distances for ',d.shape[0]

end = time.time()
print(end - start)

print 'Computing FWHM'

count=0
rmax = 1e6
fwhm_lo,fwhm_hi = np.zeros(len(d)),np.zeros(len(d))
sigma = np.zeros(len(d))
from scipy.optimize import brentq
for i in range(len(d)):
    rmode = d[i]
    M = (rmode**2*np.exp(-rmode/L)/(f['parallax_error'].values[i]/1000.))*\
        np.exp((-1./(2*(f['parallax_error'].values[i]/1000.)**2))*(f['parallax'].values[i]/1000.-(1./rmode))**2)
    lo = brentq(lambda x: 2*np.log(x)-(x/L)-((((f['parallax'].values[i]/1000.)-(1./x))**2)/(2*(f['parallax_error'].values[i]/1000.)**2)) \
               +np.log(2)-np.log(M)-np.log(f['parallax_error'].values[i]/1000.), 0.001, rmode)
    hi = brentq(lambda x: 2*np.log(x)-(x/L)-((((f['parallax'].values[i]/1000.)-(1./x))**2)/(2*(f['parallax_error'].values[i]/1000.)**2)) \
               +np.log(2)-np.log(M)-np.log(f['parallax_error'].values[i]/1000.), rmode, rmax)
    fwhm_lo[i],fwhm_hi[i] = lo,hi
    
    sigma[i] = (hi-lo)/2.355
    
    count = count+1
    mod=count%10000
    if mod==0:
        print 'Finished ',count,' sources'

print 'Finished FWHM for ',fwhm_lo.shape[0]
end = time.time()
print(end - start)
# Out:
# Computing distances
# Finished  10000  sources
# Finished  20000  sources
# Finished  30000  sources
# Finished distances for  37443
# 5.73894715309
# Computing FWHM
# Finished  10000  sources
# Finished  20000  sources
# Finished  30000  sources
# Finished FWHM for  37443
# 57.5958650112

# %%
h = pd.DataFrame({'source_id':f['source_id'],'dist':d,'fwhm_lo':fwhm_lo,'fwhm_hi':fwhm_hi,\
                  'sd':sigma})
h.to_csv('temp.csv')
#h

# %% [markdown]
# So I couldn't figure out how to upload entire columns of data into MySQL tables, apperently this is not a thing that can be done.  But Matt suggested a better way...

# %% [markdown]
# ## Another way

# %% [markdown]
# Example with the Fornax cluster field.

# %%
db = MySQLdb.connect(host='104.154.94.28',db='loganp',\
                     read_default_file="~/.my.cnf",\
                     autocommit=True,\
                     local_infile = 1)
c=db.cursor()
cursor=db.cursor()

# %%
# Create new columns on the table to be edited:
string = "ALTER TABLE meerkat_gaiadr2_mightee \
            ADD `dist.c` FLOAT NOT NULL,\
            ADD `fwhm_lo.c` FLOAT NOT NULL,\
            ADD `fwhm_hi.c` FLOAT NOT NULL,\
            ADD `sd.c` FLOAT NOT NULL"
c.execute(string)

# %%
L=1350
rmax = 1e6
c.execute("""SELECT source_id,parallax,parallax_error,bp_rp,phot_g_mean_mag,ra,decl \
                FROM meerkat_gaiadr2_laduma\
                WHERE 1 """)
numrows = c.rowcount

# %% [markdown]
# Pull out one row at a time from the query results.  Perform the math on just that row, then update the corresponding cell in the new columns of the original table that match with the same source id from the original table.
#
# NOTE - It is exceedingly faster if you index the source_id column on the original table first.  This lets MySQL search for the matching row much more quickly.  In phpmyadmin, click on "Structure", then click the little lightning bolt logo called "Index" in the source_id row.  Do this before executing the following cell.  This is much more important for the much larger tables.

# %%
for x in xrange(0,numrows):
    row = c.fetchone()
    # Compute distance:
    coeff = np.array([(1./L),(-2),((row[1]/1000.)/((row[2]/1000.))**2),\
                      -(1./((row[2]/1000.)**2))])
    g = np.roots(coeff)
    # Find the number of real roots:
    reals = np.isreal(g)
    realsum = np.sum(reals)
    # If there is one real root, that root is the  mode:
    if realsum == 1:
        d = np.real(g[np.where(reals)[0]])
    # If all roots are real:
    elif realsum == 3:
        if row[1] >= 0:
            # Take the smallest root:
            d = np.min(g)
        elif row[1] < 0:
            # Take the positive root (there should be only one):
            d = g[np.where(g>0)[0]]
    # Compute FWHM: 
    rmode = d
    M = (rmode**2*np.exp(-rmode/L)/(row[2]/1000.))*\
        np.exp((-1./(2*(row[2]/1000.)**2))*(row[1]/1000.-(1./rmode))**2)
    lo = brentq(lambda x: 2*np.log(x)-(x/L)-((((row[1]/1000.)-(1./x))**2)/(2*(row[2]/1000.)**2)) \
               +np.log(2)-np.log(M)-np.log(row[2]/1000.), 0.001, rmode)
    hi = brentq(lambda x: 2*np.log(x)-(x/L)-((((row[1]/1000.)-(1./x))**2)/(2*(row[2]/1000.)**2)) \
               +np.log(2)-np.log(M)-np.log(row[2]/1000.), rmode, rmax)
    # Compute std dev:
    sigma = (hi-lo)/2.355
    
    # Update the original table with the new values, matching by source id:
    string = """UPDATE `meerkat_gaiadr2_laduma` SET `dist.c`="""+str(d[0])+""" \
                    WHERE `source_id` ="""+str(row[0])
    cursor.execute(string)
    string = """UPDATE `meerkat_gaiadr2_laduma` SET `fwhm_lo.c`="""+str(lo)+""" \
                    WHERE `source_id` ="""+str(row[0])
    cursor.execute(string)
    string = """UPDATE `meerkat_gaiadr2_laduma` SET `fwhm_hi.c`="""+str(hi)+""" \
                    WHERE `source_id` ="""+str(row[0])
    cursor.execute(string)
    string = """UPDATE `meerkat_gaiadr2_laduma` SET `sd.c`="""+str(sigma)+""" \
                    WHERE `source_id` ="""+str(row[0])
    cursor.execute(string)
